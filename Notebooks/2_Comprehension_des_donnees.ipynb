# %% [markdown]
# <b> <a>  OBJECTIF

# %% [markdown]
# Comprendre les données avant de commencer l'analyse.

# %% [markdown]
# <b> <a>  SOURCE DES DONNEES

# %% [markdown]
# Source des données : Kaggle

# %% [markdown]
# <b> <a>  DESCRIPTION DES DONNEES

# %% [markdown]
# le dataset contient environ :
#
# 545 logements (maisons) ou encore 545 observations
#
# 12  variables explicatives
#
# 1   variable cible

# %% [markdown]
# <b> <a>  DICTIONNAIRE DES DONNEES

# %% [markdown]
# Voici les principales colonnes, avec leur signification :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> <a>  LES TYPES DE VARIABLES

# %% [markdown]
#  on distingue :
#
#  Variables numeriques     :  "area"  "bedrooms"  "bathrooms"   "stories"   "parking"
#
#  Variables categorielles  :  "mainroad"   "guestroom"  "basement"  "hotwaterheating"  "airconditioning"  "furnishingstatut"
#
#  Variable cible           :  "price"
